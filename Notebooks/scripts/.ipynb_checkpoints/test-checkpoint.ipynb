# %%
from ch6 import *

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
x   = np.random.normal(0, 1, 100)
eps = np.random.normal(0 ,1 , 100)

b0, b1, b2, b3 = [3, 2, -4, 5]
y = b0 + b1*x + b2*(x**2) + b3*(x**3) + eps

df = pd.DataFrame({'X'  : x,
                   'X2' : x**2,
                   'X3' : x**3,
                   'X4' : x**4,
                   'X5' : x**5,
                   'X6' : x**6,
                   'X7' : x**7,
                   'X8' : x**8,
                   'X9' : x**9,
                   'X10': x**10,
                   'y'  : y})

model_subsets = best_subset(X=df.columns[:10], y='y', data=df)
scores_plot(model_subsets)
# Out:
# Progess: k = 1, done, time: 0.0635 s
# Progess: k = 2, done, time: 0.3749 s
# Progess: k = 3, done, time: 1.1727 s
# Progess: k = 4, done, time: 2.7115 s
# Progess: k = 5, done, time: 3.1697 s
# Progess: k = 6, done, time: 2.9415 s
# Progess: k = 7, done, time: 1.8524 s
# Progess: k = 8, done, time: 0.7627 s
# Progess: k = 9, done, time: 0.192 s
# Progess: k = 10, done, time: 0.0239 s
# Model selected coefficients:
# Intercept    2.871015
# X            1.926693
# X2          -4.812863
# X3           5.022959
# X4           2.739873
# X6          -1.949759
# X8           0.491189
# X10         -0.038244
# dtype: float64
# ----------------------------------------------------
# Model selected coefficients:
# Intercept    2.847927
# X            1.864293
# X2          -3.793062
# X3           5.028366
# dtype: float64
# ----------------------------------------------------
# Model selected coefficients:
# Intercept    2.831634
# X            2.037134
# X2          -3.762590
# X3           4.928210
# X10         -0.000153
# dtype: float64

# %%
model_subsets_fs, _              = forward_stepwise(df.columns.drop('y'), 'y', df)
model_subsets_bs, best_models_bs = backward_stepwise(df.columns.drop('y'), 'y', df)

scores_plot(model_subsets_fs)
# Out:
# Model selected coefficients:
# Intercept    2.614566
# X3           5.611208
# X2          -3.473897
# dtype: float64
# ----------------------------------------------------
# Model selected coefficients:
# Intercept    2.614566
# X3           5.611208
# X2          -3.473897
# dtype: float64
# ----------------------------------------------------
# Model selected coefficients:
# Intercept    2.614566
# X3           5.611208
# X2          -3.473897
# dtype: float64
